# %% [markdown]
# # Baseline ITEA
#
# Execução simples de algumas repetições do ITEA para obter um baseline do desempenho do nosso algoritmo para aquela base de dados específica.
#
# (O itea aqui está na versão do mesmo utilizado para análise de sensibilidade. A versão mais atual é a do mestrado, mas conta com algumas modificações que acho que não condizem com o estado do algoritmo quando o Fabrício gerou os resultados. Além do mais, a ideia é só ter um baseline).

# %%
import os
import glob

import os.path as path
import pandas  as pd
import numpy   as np
import itea    as sr

from itertools         import product
from sklearn.metrics   import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.linear_model import LinearRegression 

from sklearn.model_selection import GridSearchCV

from IPython.display         import display, Markdown, Latex

cur_folder = os.getcwd() # Diretório atual

datasets_folder = '../datasets/'

print('Done')
# Out:
# Done

# %%
def RMSE(yhat, y):
    return np.sqrt(np.square(yhat - y).mean())

params = {
    'popsize'   : 100,
    'gens'      : 100, 
    'minterms'  : 1,
    'model'     : LinearRegression(n_jobs=-1),
    'expolim'   : (-3, 3),
    'maxterms'  : 10,
    'check_fit' : True,
    'funs'      : { # should be unary functions, f:R -> R
        'sin'      : np.sin,
        'cos'      : np.cos,
        'tan'      : np.tan,
        'abs'      : np.abs,
        'id'       : lambda x: x,
        'sqrt.abs' : lambda x: np.sqrt(np.absolute(x)),
        'log'      : np.log, 
        'exp'      : np.exp,
    }
}

# %%
n_folds = 5
n_reps  = 6

# kNN é determinístico, não precisamos fazer repetições
datasets = [
    'airfoil',
    'concrete',
    'energyCooling',
    'energyHeating',
    'GeographicalOriginalofMusic',
    'towerData',
    'tecator',
    'wineRed',
    'wineWhite',
    'yacht',
]    

# ---------------------------
columns = ['dataset','conf','Fold','Rep','RMSE_train','RMSE_test']

fname = '../docs/itea-baseline-resultsregression.csv'
results = {c:[] for c in columns}

if os.path.isfile(fname):
    resultsDF = pd.read_csv(fname)
    results   = resultsDF.to_dict('list')

for ds in datasets:
    print(f'Gridsearch para base {ds}')
    
    for fold in range(n_folds):
        dataset_train = None
        dataset_test  = None

        # evitar tentar abrir arquivos que não existem
        try:
            dataset_train = np.loadtxt(f'{datasets_folder}/{ds}-train-{fold}.dat', delimiter=',')
            dataset_test  = np.loadtxt(f'{datasets_folder}/{ds}-test-{fold}.dat', delimiter=',')
        except:
            continue

        for rep in range(n_reps):
            # Retomar testes se interrompido
            if os.path.isfile(fname):
                resultsDF = pd.read_csv(fname)
                results   = resultsDF.to_dict('list')

                if len(resultsDF[
                    (resultsDF['dataset']==ds) &
                    (resultsDF['Rep']==rep) &
                    (resultsDF['Fold']==fold)
                ])==1:
                    print(f'already evaluated {ds}-{fold}')

                    continue

            X_train, y_train = dataset_train[:, :-1], dataset_train[:, -1]
            X_test,  y_test  = dataset_test[:, :-1],  dataset_test[:, -1]

            itea    = sr.ITEA(**params)
            bestsol = itea.run(X_train, y_train, verbose=True)

            RMSE_train = RMSE(bestsol.predict(X_train).ravel(), y_train.ravel())
            RMSE_test  = RMSE(bestsol.predict(X_test).ravel(), y_test.ravel())

            # Vamos salvar o número da configuração para ficar mais sucinto
            results['dataset'].append(ds)
            results['conf'].append(params)
            results['RMSE_train'].append(RMSE_train)
            results['RMSE_test'].append(RMSE_test)
            results['Fold'].append(fold)
            results['Rep'].append(rep)


            df = pd.DataFrame(results)
            df.to_csv(fname, index=False)

print('done')
# Out:
# Gridsearch para base airfoil
# already evaluated airfoil-0
# already evaluated airfoil-0
# already evaluated airfoil-0
# already evaluated airfoil-0
# already evaluated airfoil-0
# already evaluated airfoil-0
# already evaluated airfoil-1
# already evaluated airfoil-1
# already evaluated airfoil-1
# already evaluated airfoil-1
# already evaluated airfoil-1
# already evaluated airfoil-1
# already evaluated airfoil-2
# already evaluated airfoil-2
# already evaluated airfoil-2
# already evaluated airfoil-2
# already evaluated airfoil-2
# already evaluated airfoil-2
# already evaluated airfoil-3
# already evaluated airfoil-3
# already evaluated airfoil-3
# already evaluated airfoil-3
# already evaluated airfoil-3
# already evaluated airfoil-3
# already evaluated airfoil-4
# already evaluated airfoil-4
# already evaluated airfoil-4
# already evaluated airfoil-4
# already evaluated airfoil-4
# already evaluated airfoil-4
# Gridsearch para base concrete
# already evaluated concrete-0
# already evaluated concrete-0
# already evaluated concrete-0
# already evaluated concrete-0
# already evaluated concrete-0
# already evaluated concrete-0
# already evaluated concrete-1
# already evaluated concrete-1
# already evaluated concrete-1
# already evaluated concrete-1
# already evaluated concrete-1
# already evaluated concrete-1
# already evaluated concrete-2
# already evaluated concrete-2
# already evaluated concrete-2
# already evaluated concrete-2
# already evaluated concrete-2
# already evaluated concrete-2
# already evaluated concrete-3
# already evaluated concrete-3
# already evaluated concrete-3
# already evaluated concrete-3
# already evaluated concrete-3
# already evaluated concrete-3
# already evaluated concrete-4
# already evaluated concrete-4
# already evaluated concrete-4
# already evaluated concrete-4
# already evaluated concrete-4
# already evaluated concrete-4
# Gridsearch para base energyCooling
# already evaluated energyCooling-0
# already evaluated energyCooling-0
# already evaluated energyCooling-0
# already evaluated energyCooling-0
# already evaluated energyCooling-0
# already evaluated energyCooling-0
# already evaluated energyCooling-1
# already evaluated energyCooling-1
# already evaluated energyCooling-1
# already evaluated energyCooling-1
# already evaluated energyCooling-1
# already evaluated energyCooling-1
# already evaluated energyCooling-2
# already evaluated energyCooling-2
# already evaluated energyCooling-2
# already evaluated energyCooling-2
# already evaluated energyCooling-2
# already evaluated energyCooling-2
# already evaluated energyCooling-3
# already evaluated energyCooling-3
# already evaluated energyCooling-3
# already evaluated energyCooling-3
# already evaluated energyCooling-3
# already evaluated energyCooling-3
# already evaluated energyCooling-4
# already evaluated energyCooling-4
# already evaluated energyCooling-4
# already evaluated energyCooling-4
# already evaluated energyCooling-4
# already evaluated energyCooling-4
# Gridsearch para base energyHeating
# already evaluated energyHeating-0
# already evaluated energyHeating-0
# already evaluated energyHeating-0
# already evaluated energyHeating-0
# already evaluated energyHeating-0
# already evaluated energyHeating-0
# already evaluated energyHeating-1
# already evaluated energyHeating-1
# already evaluated energyHeating-1
# already evaluated energyHeating-1
# already evaluated energyHeating-1
# already evaluated energyHeating-1
# already evaluated energyHeating-2
# already evaluated energyHeating-2
# already evaluated energyHeating-2
# already evaluated energyHeating-2
# already evaluated energyHeating-2
# already evaluated energyHeating-2
# already evaluated energyHeating-3
# already evaluated energyHeating-3
# already evaluated energyHeating-3
# already evaluated energyHeating-3
# already evaluated energyHeating-3
# already evaluated energyHeating-3
# already evaluated energyHeating-4
# already evaluated energyHeating-4
# already evaluated energyHeating-4
# already evaluated energyHeating-4
# already evaluated energyHeating-4
# already evaluated energyHeating-4
# Gridsearch para base GeographicalOriginalofMusic
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-0
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-1
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-2
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-3
# already evaluated GeographicalOriginalofMusic-4
# already evaluated GeographicalOriginalofMusic-4
# already evaluated GeographicalOriginalofMusic-4
# already evaluated GeographicalOriginalofMusic-4
# already evaluated GeographicalOriginalofMusic-4
# already evaluated GeographicalOriginalofMusic-4
# Gridsearch para base towerData
# already evaluated towerData-0
# already evaluated towerData-0
# already evaluated towerData-0
# already evaluated towerData-0
# already evaluated towerData-0
# already evaluated towerData-0
# already evaluated towerData-1
# already evaluated towerData-1
# already evaluated towerData-1
# already evaluated towerData-1
# already evaluated towerData-1
# already evaluated towerData-1
# already evaluated towerData-2
# already evaluated towerData-2
# already evaluated towerData-2
# already evaluated towerData-2
# already evaluated towerData-2
# already evaluated towerData-2
# already evaluated towerData-3
# already evaluated towerData-3
# already evaluated towerData-3
# already evaluated towerData-3
# already evaluated towerData-3
# already evaluated towerData-3
# already evaluated towerData-4
# already evaluated towerData-4
# already evaluated towerData-4
# already evaluated towerData-4
# already evaluated towerData-4
# already evaluated towerData-4
# Gridsearch para base tecator
# already evaluated tecator-0
# already evaluated tecator-0
# already evaluated tecator-0
# already evaluated tecator-0
# already evaluated tecator-0
# already evaluated tecator-0
# already evaluated tecator-1
# already evaluated tecator-1
# already evaluated tecator-1
# already evaluated tecator-1
# already evaluated tecator-1
# already evaluated tecator-1
# already evaluated tecator-2
# already evaluated tecator-2
# already evaluated tecator-2
# already evaluated tecator-2
# already evaluated tecator-2
# already evaluated tecator-2
# already evaluated tecator-3
# already evaluated tecator-3
# already evaluated tecator-3
# already evaluated tecator-3
# already evaluated tecator-3
# already evaluated tecator-3
# already evaluated tecator-4
# already evaluated tecator-4
# already evaluated tecator-4
# already evaluated tecator-4
# already evaluated tecator-4
# already evaluated tecator-4
# Gridsearch para base wineRed
# already evaluated wineRed-0
# already evaluated wineRed-0
# already evaluated wineRed-0
# already evaluated wineRed-0
# already evaluated wineRed-0
# already evaluated wineRed-0
# already evaluated wineRed-1
# already evaluated wineRed-1
# already evaluated wineRed-1
# already evaluated wineRed-1
# already evaluated wineRed-1
# already evaluated wineRed-1
# already evaluated wineRed-2
# already evaluated wineRed-2
# already evaluated wineRed-2
# already evaluated wineRed-2
# already evaluated wineRed-2
# already evaluated wineRed-2
# already evaluated wineRed-3
# already evaluated wineRed-3
# already evaluated wineRed-3
# already evaluated wineRed-3
# already evaluated wineRed-3
# already evaluated wineRed-3
# already evaluated wineRed-4
# already evaluated wineRed-4
# already evaluated wineRed-4
# already evaluated wineRed-4
# already evaluated wineRed-4
# already evaluated wineRed-4
# Gridsearch para base wineWhite
# already evaluated wineWhite-0
# already evaluated wineWhite-0
# already evaluated wineWhite-0
# already evaluated wineWhite-0
# already evaluated wineWhite-0
# already evaluated wineWhite-0
# already evaluated wineWhite-1
# already evaluated wineWhite-1
# already evaluated wineWhite-1
# already evaluated wineWhite-1
# already evaluated wineWhite-1
# already evaluated wineWhite-1
# already evaluated wineWhite-2
# already evaluated wineWhite-2
# already evaluated wineWhite-2
# already evaluated wineWhite-2
# already evaluated wineWhite-2
# already evaluated wineWhite-2
# already evaluated wineWhite-3
# already evaluated wineWhite-3
# already evaluated wineWhite-3
# already evaluated wineWhite-3
# already evaluated wineWhite-3
# already evaluated wineWhite-3
# already evaluated wineWhite-4
# already evaluated wineWhite-4
# already evaluated wineWhite-4
# already evaluated wineWhite-4
# already evaluated wineWhite-4
# already evaluated wineWhite-4
# Gridsearch para base yacht
# already evaluated yacht-0
# already evaluated yacht-0
# already evaluated yacht-0
# already evaluated yacht-0
# already evaluated yacht-0
# already evaluated yacht-0
# already evaluated yacht-1
# already evaluated yacht-1
# already evaluated yacht-1
# already evaluated yacht-1
# already evaluated yacht-1
# already evaluated yacht-1
# already evaluated yacht-2
# already evaluated yacht-2
# already evaluated yacht-2
# already evaluated yacht-2
# already evaluated yacht-2
# already evaluated yacht-2
# already evaluated yacht-3
# already evaluated yacht-3
# already evaluated yacht-3
# already evaluated yacht-3
# already evaluated yacht-3
# already evaluated yacht-3
# already evaluated yacht-4
# already evaluated yacht-4
# already evaluated yacht-4
# already evaluated yacht-4
# already evaluated yacht-4
# already evaluated yacht-4
# done

# %%
fname = '../docs/itea-baseline-resultsregression.csv'

resultsDF = pd.read_csv(fname)

pd.set_option('display.max_colwidth', None) #não truncar colunas usando display

display(Markdown('## Tabela dos resultados'))
display(resultsDF)

# Obtendo a melhor configuração para cada dataset

# Calculando as medianas e tirando a coluna de fold e rep (configuração já some pois não é numérico)
resultsDF_median = resultsDF.groupby('dataset').mean().iloc[:, 2:]
resultsDF_median.columns = ['RMSE_train_mean', 'RMSE_test_mean']
display(Markdown('## Médias dos folds para cada dataset'))
display(resultsDF_median)

# Colocando o desvio padrão 
resultsDF_std = resultsDF.groupby('dataset').std().iloc[:, 2:]
resultsDF_std.columns = ['RMSE_train_std', 'RMSE_test_std']
display(Markdown('## Desvios padrões dos folds para cada dataset'))
display(resultsDF_std)

# juntando tudo em um só
resultsDF_ = pd.merge(resultsDF_median, resultsDF_std, left_index=True, right_index=True)
display(Markdown('## Juntando tudo'))
display(resultsDF_)
# Out:
# ## Tabela dos resultados
#      dataset  \
# 0    airfoil
# 1    airfoil
# 2    airfoil
# 3    airfoil
# 4    airfoil
# ..       ...
# 295    yacht
# 296    yacht
# 297    yacht
# 298    yacht
# 299    yacht
#
#                                                                                                                                                                                                                                                                                                                                                                                              conf  \
# 0    {'popsize': 150, 'gens': 150, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x7f41873c91e0>, 'sqrt.abs': <function <lambda> at 0x7f41873c9268>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 1    {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x7f41873c90d0>, 'sqrt.abs': <function <lambda> at 0x7f4181ec5a60>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 2    {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x7f41873c90d0>, 'sqrt.abs': <function <lambda> at 0x7f4181ec5a60>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 3    {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x7f41873c90d0>, 'sqrt.abs': <function <lambda> at 0x7f4181ec5a60>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 4    {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x7f41873c90d0>, 'sqrt.abs': <function <lambda> at 0x7f4181ec5a60>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# ..                                                                                                                                                                                                                                                                                                                                                                                            ...
# 295        {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x125077f70>, 'sqrt.abs': <function <lambda> at 0x125080040>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 296        {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x125077f70>, 'sqrt.abs': <function <lambda> at 0x125080040>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 297        {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x125077f70>, 'sqrt.abs': <function <lambda> at 0x125080040>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 298        {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x125077f70>, 'sqrt.abs': <function <lambda> at 0x125080040>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
# 299        {'popsize': 100, 'gens': 100, 'minterms': 1, 'model': LinearRegression(n_jobs=-1), 'expolim': (-3, 3), 'maxterms': 10, 'check_fit': True, 'funs': {'sin': <ufunc 'sin'>, 'cos': <ufunc 'cos'>, 'tan': <ufunc 'tan'>, 'abs': <ufunc 'absolute'>, 'id': <function <lambda> at 0x125077f70>, 'sqrt.abs': <function <lambda> at 0x125080040>, 'log': <ufunc 'log'>, 'exp': <ufunc 'exp'>}}
#
#      Fold  Rep  RMSE_train  RMSE_test
# 0       0    0    2.707667   2.843225
# 1       0    1    3.148132   3.195676
# 2       0    2    2.893684   3.107116
# 3       0    3    2.944998   3.066274
# 4       0    4    3.295039   3.378448
# ..    ...  ...         ...        ...
# 295     4    1    0.851588   0.871739
# 296     4    2    0.881112   1.014850
# 297     4    3    0.892489   0.966062
# 298     4    4    0.974923   1.240174
# 299     4    5    0.891747   1.161469
#
# [300 rows x 6 columns]
# ## Médias dos folds para cada dataset
#                              RMSE_train_mean  RMSE_test_mean
# dataset
# GeographicalOriginalofMusic        48.183360    4.682373e+14
# airfoil                             2.936392    3.088888e+00
# concrete                            7.650309    7.823005e+00
# energyCooling                       2.082467    2.108696e+00
# energyHeating                       1.576629    1.623726e+00
# tecator                             2.628510    6.818481e+03
# towerData                          36.088581    3.777610e+01
# wineRed                             0.629096    6.518551e-01
# wineWhite                           0.732906    7.477114e-01
# yacht                               1.060983    1.294642e+00
# ## Desvios padrões dos folds para cada dataset
#                              RMSE_train_std  RMSE_test_std
# dataset
# GeographicalOriginalofMusic        0.560404   2.564641e+15
# airfoil                            0.170263   2.627643e-01
# concrete                           0.983005   1.034273e+00
# energyCooling                      0.388417   4.634189e-01
# energyHeating                      0.636519   6.266630e-01
# tecator                            0.081789   3.714973e+04
# towerData                          3.209620   9.428280e+00
# wineRed                            0.009295   3.988568e-02
# wineWhite                          0.005784   5.155972e-02
# yacht                              0.264718   3.983809e-01
# ## Juntando tudo
#                              RMSE_train_mean  RMSE_test_mean  RMSE_train_std  \
# dataset
# GeographicalOriginalofMusic        48.183360    4.682373e+14        0.560404
# airfoil                             2.936392    3.088888e+00        0.170263
# concrete                            7.650309    7.823005e+00        0.983005
# energyCooling                       2.082467    2.108696e+00        0.388417
# energyHeating                       1.576629    1.623726e+00        0.636519
# tecator                             2.628510    6.818481e+03        0.081789
# towerData                          36.088581    3.777610e+01        3.209620
# wineRed                             0.629096    6.518551e-01        0.009295
# wineWhite                           0.732906    7.477114e-01        0.005784
# yacht                               1.060983    1.294642e+00        0.264718
#
#                              RMSE_test_std
# dataset
# GeographicalOriginalofMusic   2.564641e+15
# airfoil                       2.627643e-01
# concrete                      1.034273e+00
# energyCooling                 4.634189e-01
# energyHeating                 6.266630e-01
# tecator                       3.714973e+04
# towerData                     9.428280e+00
# wineRed                       3.988568e-02
# wineWhite                     5.155972e-02
# yacht                         3.983809e-01
